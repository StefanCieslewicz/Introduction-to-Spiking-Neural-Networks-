# %% [markdown]
# Project overview
#
#
# Bio data taken from [A large neuronal dataset for natural category-based free-gaze visual search in macaques](https://osf.io/sdgkr/overview)

# %% [markdown]
# monke
#
# not perceptual similarity
#
# kinda shit comparison

# %% [markdown]
# References:
#
#  	Zhang, J., Zhu, X., Zhou, H. et al. A large neuronal dataset for natural category-based free-gaze visual search in macaques. Sci Data 12, 779 (2025). https://doi.org/10.1038/s41597-025-05130-5
#
# 	Chang, Mindy & Wang, Ge & Berger, Jonathan. (2010). Sonification and Visualization of Neural Data.
